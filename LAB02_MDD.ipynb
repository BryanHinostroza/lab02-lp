# %% [markdown]
# <a href="https://colab.research.google.com/github/BryanHinostroza/lab02-lp/blob/develop/LAB02_MDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SEMANA 2: METODOLOGÍA CRISP-DM. METODOLOGÍA SEMMA**

# %%
# !pip install pycaret mlflow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Crear la carpeta si no existe
os.makedirs('/content/drive/MyDrive/modelos_clf', exist_ok=True)

# %%
import pandas as pd

# Cargar los datos
data = pd.read_csv('/content/drive/MyDrive/diabetes.csv')

# %%
from pycaret.classification import *

# Inicializar el entorno
clf = setup(data, target='Outcome', session_id = 123)
# Out:
# <style type="text/css">
# #T_24c14_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_24c14" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24c14_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_24c14_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24c14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24c14_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_24c14_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_24c14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_24c14_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_24c14_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_24c14_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_95a94 th {
#   text-align: left;
# }
# ...

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_0d1c1_row10_col0, #T_0d1c1_row10_col1, #T_0d1c1_row10_col2, #T_0d1c1_row10_col3, #T_0d1c1_row10_col4, #T_0d1c1_row10_col5, #T_0d1c1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0d1c1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d1c1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0d1c1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0d1c1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0d1c1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0d1c1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0d1c1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0d1c1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(best_model)
print(predictions.head())
# Out:
# <style type="text/css">
# </style>
# <table id="T_676c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_676c5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_676c5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_676c5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_676c5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_676c5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_676c5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_676c5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_676c5_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_676c5_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
import joblib

# Guardar el modelo ajustado
model_path = '/content/drive/MyDrive/modelos_clf/tuned_model.pkl'
joblib.dump(tuned_model, model_path)
# Out:
# ['/content/drive/MyDrive/modelos_clf/tuned_model.pkl']

# %%
import mlflow

# Configurar el experimento
mlflow.set_experiment('modelo_diabetes')

# Iniciar el seguimiento
with mlflow.start_run():
    # Guardar el modelo ajustado
    mlflow.log_artifact(model_path)
# Out:
# 2025/03/27 01:55:13 INFO mlflow.tracking.fluent: Experiment with name 'modelo_diabetes' does not exist. Creating a new experiment.

# %%
# Listar el contenido de la carpeta para verificar
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Latinoamericano-arte.mp4',
#  'ACDC - Shoot to Thrill (Guitar Backing Track).mp3',
#  'ac dc maqueta.mp4',
#  'Shoot To Thrill Backing Track - ACDC.mp3',
#  'Green Day - 21 Guns [Guitar Backing Track].mp3',
#  'Hackaton 2024.gdoc',
#  'Integrantes-Proyecto Banda de Rock.gsheet',
#  'Technology Schools',
#  'Conversa ',
#  'Tarea Bryan',
#  '9agosto',
#  'Reunión 20 aniversario.gdoc',
#  'Colab Notebooks',
#  'GLAB-S01-GRUPAL-2024-08-20.docx',
#  'Hinostroza Martinez-TE.docx',
#  'T.Emergentes Laboratorio 1_ Mosquito - IoT (4).docx',
#  'HINOSTROZA MARTINEZ- 29 agosto-TE.docx',
#  'Grupos_Bélgica_5to.xlsx',
#  'TS_Registros',
#  'GAD-2024',
#  'Ficha y Tarea_ 4to primaria_Aritmética.docx',
#  'Ficha y Tarea_ 3ro primaria_Geometría.docx',
#  'Ficha y Tarea_ 6to primaria_Geometría.docx',
#  'Ficha y Tarea_ 4to primaria_Geometría.docx',
#  'Sesiones de clase',
#  'Final T.E.gslides',
#  'Presentación proyecto útiles escolares creativo divertido aguamarina.gslides',
# ...

# %%
import os

# Listar el contenido de la carpeta modelos_clf
os.listdir('/content/drive/MyDrive/modelos_clf')
# Out:
# ['tuned_model.pkl']
